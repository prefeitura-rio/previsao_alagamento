# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import acf, pacf
from sklearn.metrics import confusion_matrix

# %%
#criando uma série temporal de teste
ts = pd.Series(np.random.randn(100), index=pd.date_range('today', periods=100))
ts
# Out:
# 2023-11-08 16:57:41.943935    0.061815
# 2023-11-09 16:57:41.943935    0.584378
# 2023-11-10 16:57:41.943935   -0.379197
# 2023-11-11 16:57:41.943935   -1.939328
# 2023-11-12 16:57:41.943935    0.378181
#                                 ...
# 2024-02-11 16:57:41.943935   -0.214551
# 2024-02-12 16:57:41.943935    0.798977
# 2024-02-13 16:57:41.943935    1.358585
# 2024-02-14 16:57:41.943935    0.074724
# 2024-02-15 16:57:41.943935   -0.382965
# Freq: D, Length: 100, dtype: float64

# %%
#calculanado a ACF e PACF respectivamente
lag_acf = acf(ts, nlags=20)
lag_pacf = pacf(ts, nlags=20, method='ols')

# %%
#plotando a ACF
plt.figure(figsize=(12, 6))
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts)), linestyle='--', color='gray')
plt.title('Autocorrelation Function')
plt.tight_layout()
plt.show()

# %%
#plotando a PACF
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts)), linestyle='--', color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()
plt.show()
